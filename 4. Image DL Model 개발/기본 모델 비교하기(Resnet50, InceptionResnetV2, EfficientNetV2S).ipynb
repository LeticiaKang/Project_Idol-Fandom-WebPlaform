# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import tensorflow.keras as k
from tensorflow.keras.preprocessing import image

from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2S
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.applications.resnet50 import ResNet50

from tensorflow.keras.models import Model
import tensorflow.keras.layers as layers
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, GlobalMaxPooling2D
from tensorflow.keras.optimizers import Adam
import numpy as np

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from time import perf_counter, sleep

# %%
# Data augmentation
def augmentation(target_size, batch_size, class_mode="categorical"):
  # print("start")
  train_datagen = ImageDataGenerator(rescale = 1./255,
                                    shear_range = 0.2,
                                    zoom_range = 0.2,
                                    rotation_range=120, 
                                    horizontal_flip = True)

  test_datagen = ImageDataGenerator(rescale = 1./255)

  # Generate training and test sets
  train_set = train_datagen.flow_from_directory(r'/content/drive/MyDrive/테스트용/train',
                                                  target_size = (target_size,target_size),
                                                  batch_size = batch_size,
                                                  class_mode = 'categorical')

  test_set = test_datagen.flow_from_directory(r'/content/drive/MyDrive/테스트용/test',
                                              target_size = (target_size,target_size),                                              # target_size = (299,299),
                                              batch_size = batch_size,
                                              class_mode = 'categorical')

  val_set = test_datagen.flow_from_directory(r'/content/drive/MyDrive/테스트용/val',
                                              target_size = (target_size,target_size),
                                              batch_size = batch_size,
                                              class_mode = 'categorical')
  # print("end")
  print("================================================================================================================")
  return train_set, test_set,val_set

def result_graph(history, model, test_set):
   # show the graph of train and validation loss/acc 
  import matplotlib.pyplot as plt
  fig, loss = plt.subplots()

  acc = loss.twinx()

  loss.plot(history.history['loss'], 'y', label='train loss')
  loss.plot(history.history['val_loss'], 'r', label='val loss')

  acc.plot(history.history['accuracy'], 'b', label='train acc')
  acc.plot(history.history['val_accuracy'], 'g', label='val acc')

  loss.set_xlabel('epoch')
  loss.set_ylabel('loss')
  acc.set_ylabel('accuray')

  loss.legend(loc='upper left')
  acc.legend(loc='lower left')

  plt.grid()
  plt.show()
  print("================================================================================================================")

  # Evaluate the model on the test set
  result= model.evaluate_generator(test_set) #test_loss, test_acc # ★change
  print('loss:', round(result[0]))
  print('accuracy:', round(result[1], 5))

# %% [markdown]
# ## InceptionResnet_V2

# %%
def for_inception_v2(base_model, epoch=20, optimizer="adam", class_num = 8,
                   pooling = GlobalAveragePooling2D(), dense_num = 1024):
  train_set, test_set,val_set = augmentation(299, 32, class_mode="categorical")

  # # freezen the layers
  for layer in base_model.layers:
      layer.trainable = False
 

  # Add a GlobalAveragePooling layer
  x = base_model.output
  x = pooling(x)  # ★change
  x = Dense(dense_num, activation = 'relu')(x) # ★change
  # fix a number of classes
  predictions = Dense(class_num, activation='softmax')(x) # ★change

  # compile the model
  model = Model(inputs=base_model.input, outputs=predictions)
  model.compile(
    optimizer = optimizer, # ★change
    loss='categorical_crossentropy',
    metrics=['accuracy']
  )

  # fit the model
  start = perf_counter()
  history = model.fit(train_set, epochs = epoch, validation_data = val_set) # ★change # ★change # ★change
  end = perf_counter()

  # print the learning time
  print(f"Time : {end-start}")

  result_graph(history, model, test_set)

  return history, model, test_set

# %%
input_tensor = tf.keras.layers.Input(shape=(299, 299, 3))

base_model = InceptionResNetV2(weights='imagenet', include_top=False,input_tensor=input_tensor)

for_inception_v2(base_model, epoch=30, optimizer="adam", class_num = 8,
                   pooling = GlobalMaxPooling2D(), dense_num = 1024)
# Out:
# Found 221 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# ================================================================================================================
# Epoch 1/30
# 7/7 [==============================] - 27s 3s/step - loss: 26.2131 - accuracy: 0.1176 - val_loss: 25.4001 - val_accuracy: 0.1233
# Epoch 2/30
# 7/7 [==============================] - 12s 2s/step - loss: 21.0830 - accuracy: 0.1267 - val_loss: 12.8229 - val_accuracy: 0.1233
# Epoch 3/30
# 7/7 [==============================] - 12s 2s/step - loss: 7.7894 - accuracy: 0.2760 - val_loss: 3.5698 - val_accuracy: 0.2466
# Epoch 4/30
# 7/7 [==============================] - 12s 2s/step - loss: 3.5259 - accuracy: 0.2262 - val_loss: 2.6707 - val_accuracy: 0.3836
# Epoch 5/30
# 7/7 [==============================] - 12s 2s/step - loss: 2.4281 - accuracy: 0.3122 - val_loss: 2.1670 - val_accuracy: 0.3425
# Epoch 6/30
# 7/7 [==============================] - 12s 2s/step - loss: 2.0726 - accuracy: 0.4344 - val_loss: 1.5640 - val_accuracy: 0.3836
# Epoch 7/30
# 7/7 [==============================] - 12s 2s/step - loss: 1.4424 - accuracy: 0.4796 - val_loss: 1.3859 - val_accuracy: 0.6438
# Epoch 8/30
# 7/7 [==============================] - 12s 2s/step - loss: 1.1992 - accuracy: 0.5973 - val_loss: 1.1077 - val_accuracy: 0.6301
# Epoch 9/30
# 7/7 [==============================] - 13s 2s/step - loss: 1.1225 - accuracy: 0.6290 - val_loss: 1.1362 - val_accuracy: 0.6438
# Epoch 10/30
# 7/7 [==============================] - 12s 2s/step - loss: 1.0507 - accuracy: 0.6380 - val_loss: 1.0217 - val_accuracy: 0.6712
# Epoch 11/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.9901 - accuracy: 0.6516 - val_loss: 1.2489 - val_accuracy: 0.6027
# Epoch 12/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.7980 - accuracy: 0.7602 - val_loss: 0.8790 - val_accuracy: 0.7534
# Epoch 13/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.6628 - accuracy: 0.8190 - val_loss: 0.8793 - val_accuracy: 0.6438
# Epoch 14/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.6974 - accuracy: 0.7964 - val_loss: 0.8978 - val_accuracy: 0.6849
# Epoch 15/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.7536 - accuracy: 0.7330 - val_loss: 1.0672 - val_accuracy: 0.6849
# Epoch 16/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.7129 - accuracy: 0.7783 - val_loss: 0.9247 - val_accuracy: 0.6986
# Epoch 17/30
# 7/7 [==============================] - 13s 2s/step - loss: 0.7541 - accuracy: 0.7647 - val_loss: 0.9603 - val_accuracy: 0.6301
# Epoch 18/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.7720 - accuracy: 0.7557 - val_loss: 0.9416 - val_accuracy: 0.6986
# Epoch 19/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.8334 - accuracy: 0.7014 - val_loss: 0.9877 - val_accuracy: 0.6986
# Epoch 20/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.8501 - accuracy: 0.7511 - val_loss: 1.0114 - val_accuracy: 0.6986
# Epoch 21/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.7418 - accuracy: 0.7602 - val_loss: 0.7886 - val_accuracy: 0.7123
# Epoch 22/30
# 7/7 [==============================] - 13s 2s/step - loss: 0.7117 - accuracy: 0.7557 - val_loss: 1.1196 - val_accuracy: 0.6164
# Epoch 23/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.7643 - accuracy: 0.7466 - val_loss: 1.0149 - val_accuracy: 0.6712
# Epoch 24/30
# 7/7 [==============================] - 13s 2s/step - loss: 0.6813 - accuracy: 0.7692 - val_loss: 1.0100 - val_accuracy: 0.7534
# Epoch 25/30
# 7/7 [==============================] - 13s 2s/step - loss: 0.6501 - accuracy: 0.8054 - val_loss: 1.0232 - val_accuracy: 0.6986
# Epoch 26/30
# 7/7 [==============================] - 13s 2s/step - loss: 0.6881 - accuracy: 0.8054 - val_loss: 0.9856 - val_accuracy: 0.6986
# Epoch 27/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.5516 - accuracy: 0.8235 - val_loss: 0.9642 - val_accuracy: 0.6849
# Epoch 28/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.4947 - accuracy: 0.8326 - val_loss: 0.7898 - val_accuracy: 0.7397
# Epoch 29/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.5077 - accuracy: 0.8281 - val_loss: 0.7974 - val_accuracy: 0.7534
# Epoch 30/30
# 7/7 [==============================] - 13s 2s/step - loss: 0.4816 - accuracy: 0.8507 - val_loss: 0.9698 - val_accuracy: 0.7260
# Time : 390.8385202899999
# ================================================================================================================
# <ipython-input-9-211290430dbe>:56: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   result= model.evaluate_generator(test_set) #test_loss, test_acc # ★change
# loss: 1
# accuracy: 0.71233
# (<keras.callbacks.History at 0x7fb017cdecd0>,
#  <keras.engine.functional.Functional at 0x7fb0d8337850>,
#  <keras.preprocessing.image.DirectoryIterator at 0x7fb017c94b80>)

# %% [markdown]
# ## Resnet50

# %% [markdown]
# def for_resnet_50

# %%
# pip install tensorflow-addons

# %%
import tensorflow_addons as tfa

# %%
def for_resnet_50(base_model, epoch = 50, target_size=224, batch_size=32, optimizer = Adam(lr=1e-6), class_num = 8, pool_size = (7,7)):
  
  train_set, test_set,val_set = augmentation(target_size, batch_size, class_mode="categorical")

  # freezen the layers
  for layer in base_model.layers[:-3]:
      layer.trainable = False

  # Add a GlobalAveragePooling layer
  x = base_model.output
  x = layers.AveragePooling2D(pool_size = pool_size)(x)  # ★change
  x = layers.Flatten()(x)
  x = layers.Dropout(0.5)(x)
  # fix a number of classes
  predictions = Dense(class_num, activation='softmax')(x) # ★change

  # compile the model
  model = Model(inputs=base_model.input, outputs=predictions)
  model.compile(
    optimizer = optimizer, # ★change
    loss='categorical_crossentropy',
    metrics=['accuracy']
  )

  # fit the model
  start = perf_counter()
  history = model.fit(train_set, epochs = epoch, validation_data = val_set) # ★change # ★change # ★change
  end = perf_counter()

  # print the learning time
  print(f"Time : {end-start}")

  result_graph(history, model, test_set)

  return history, model, test_set
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
adam = tf.keras.optimizers.experimental.Adadelta(learning_rate=0.0001)

# %%
input_tensor = tf.keras.layers.Input(shape=(224, 224, 3))

base_model = ResNet50(weights='imagenet', include_top = False,input_tensor = input_tensor)

history, model, test_set = for_resnet_50(base_model, target_size = 224, batch_size=16, 
                                         epoch = 20, optimizer = adam, class_num = 8, pool_size = (7,7))
# Out:
# Found 221 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# ================================================================================================================
# Epoch 1/50
# ---------------------------------------------------------------------------
# StagingError                              Traceback (most recent call last)
# <ipython-input-56-71197e29b5f2> in <module>
#       3 base_model = ResNet50(weights='imagenet', include_top = False,input_tensor = input_tensor)
#       4
# ----> 5 history, model, test_set = for_resnet_50(base_model, target_size = 224, batch_size=16,
#       6                                          epoch = 50, optimizer = adam, class_num = 8, pool_size = (7,7))
#
# <ipython-input-55-d4483b267c04> in for_resnet_50(base_model, epoch, target_size, batch_size, optimizer, class_num, pool_size)
#      30   # fit the model
#      31   start = perf_counter()
# ---> 32   history = model.fit(train_set, epochs = epoch, validation_data = val_set) # ★change # ★change # ★change
#      33   end = perf_counter()
#      34
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1267           except Exception as e:  # pylint:disable=broad-except
#    1268             if hasattr(e, "ag_error_metadata"):
# -> 1269               raise e.ag_error_metadata.to_exception(e)
#    1270             else:
#    1271               raise
#
# StagingError: in user code:
#
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 1249, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 208, in _update_step_xla  *
#         return self._update_step(gradient, variable)
#     File "/usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 216, in _update_step  **
#         raise KeyError(
#
#     KeyError: 'The optimizer cannot recognize variable conv5_block3_3_bn/gamma:0. This usually means you are trying to call the optimizer to update different parts of the model separately. Please call `optimizer.build(variables)` with the full list of trainable variables before the training loop or use legacy optimizer `tf.keras.optimizers.legacy.{self.__class__.__name__}.'

# %% [markdown]
# ## EfficientNetV2S

# %% [markdown]
# def for_efficientnet_V2_S

# %%
def for_efficientnet_V2_S(base_model = base_model, target_size = 128, batch_size = 32, epoch = 50, optimizer = Adam(lr=1e-6), class_num = 8, dense_num = 256):
  
  train_set, test_set,val_set = augmentation(target_size, batch_size, class_mode="categorical")

  # freezen the layers
  for layer in base_model.layers[:-3]:
      layer.trainable = False

  # Add a GlobalAveragePooling layer
  x = base_model.output
  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(dense_num, activation='relu')(x)   # ★change
  x = layers.Flatten()(x)
  predictions = Dense(class_num, activation='softmax')(x) # ★change

  # compile the model
  model = Model(inputs=base_model.input, outputs=predictions)
  model.compile(
    optimizer = optimizer, # ★change
    loss='categorical_crossentropy',
    metrics=['accuracy']
  )

  # fit the model
  start = perf_counter()
  history = model.fit(train_set, epochs = epoch, validation_data = val_set) # ★change # ★change # ★change
  end = perf_counter()

  # print the learning time
  print(f"Time : {end-start}")

  result_graph(history, model, test_set)
  
  return history, model, test_set
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
# avgpooling 넣기 전
adam = tf.keras.optimizers.experimental.Adadelta(learning_rate=0.0001)

input_tensor = tf.keras.layers.Input(shape=(128, 128, 3))

base_model = EfficientNetV2S(weights='imagenet', include_top=False,input_tensor=input_tensor)

history, model, test_set = for_efficientnet_V2_S(base_model = base_model, target_size = 128, batch_size = 32,
                                                     epoch = 50, optimizer = adam, class_num = 8, dense_num = 256)
# Out:
# Found 221 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# ================================================================================================================
# Epoch 1/50
# 7/7 [==============================] - 26s 2s/step - loss: 2.0960 - accuracy: 0.1222 - val_loss: 2.1090 - val_accuracy: 0.0822
# Epoch 2/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0760 - accuracy: 0.1222 - val_loss: 2.0978 - val_accuracy: 0.1233
# Epoch 3/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0941 - accuracy: 0.1176 - val_loss: 2.0948 - val_accuracy: 0.1096
# Epoch 4/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0877 - accuracy: 0.1176 - val_loss: 2.0934 - val_accuracy: 0.1096
# Epoch 5/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0773 - accuracy: 0.1312 - val_loss: 2.0935 - val_accuracy: 0.1096
# Epoch 6/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0883 - accuracy: 0.1403 - val_loss: 2.0932 - val_accuracy: 0.1096
# Epoch 7/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0843 - accuracy: 0.1312 - val_loss: 2.0928 - val_accuracy: 0.1096
# Epoch 8/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0943 - accuracy: 0.1176 - val_loss: 2.0928 - val_accuracy: 0.1096
# Epoch 9/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0833 - accuracy: 0.1222 - val_loss: 2.0936 - val_accuracy: 0.1233
# Epoch 10/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0730 - accuracy: 0.1176 - val_loss: 2.0940 - val_accuracy: 0.1233
# Epoch 11/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0898 - accuracy: 0.1267 - val_loss: 2.0925 - val_accuracy: 0.1233
# Epoch 12/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0980 - accuracy: 0.1131 - val_loss: 2.0923 - val_accuracy: 0.1233
# Epoch 13/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0866 - accuracy: 0.1176 - val_loss: 2.0926 - val_accuracy: 0.1233
# Epoch 14/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0909 - accuracy: 0.1176 - val_loss: 2.0919 - val_accuracy: 0.1233
# Epoch 15/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0828 - accuracy: 0.0995 - val_loss: 2.0928 - val_accuracy: 0.1233
# Epoch 16/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0852 - accuracy: 0.1131 - val_loss: 2.0929 - val_accuracy: 0.1233
# Epoch 17/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0955 - accuracy: 0.1131 - val_loss: 2.0924 - val_accuracy: 0.1233
# Epoch 18/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0898 - accuracy: 0.1176 - val_loss: 2.0928 - val_accuracy: 0.1233
# Epoch 19/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0792 - accuracy: 0.1222 - val_loss: 2.0930 - val_accuracy: 0.1233
# Epoch 20/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0831 - accuracy: 0.1222 - val_loss: 2.0929 - val_accuracy: 0.1233
# Epoch 21/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0835 - accuracy: 0.1176 - val_loss: 2.0923 - val_accuracy: 0.1233
# Epoch 22/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0848 - accuracy: 0.1176 - val_loss: 2.0927 - val_accuracy: 0.1233
# Epoch 23/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0893 - accuracy: 0.1131 - val_loss: 2.0924 - val_accuracy: 0.1233
# Epoch 24/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0909 - accuracy: 0.1222 - val_loss: 2.0922 - val_accuracy: 0.1233
# Epoch 25/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0857 - accuracy: 0.1041 - val_loss: 2.0920 - val_accuracy: 0.1233
# Epoch 26/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0902 - accuracy: 0.1176 - val_loss: 2.0924 - val_accuracy: 0.1233
# Epoch 27/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0993 - accuracy: 0.1131 - val_loss: 2.0923 - val_accuracy: 0.1233
# Epoch 28/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0765 - accuracy: 0.1357 - val_loss: 2.0917 - val_accuracy: 0.1233
# Epoch 29/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0911 - accuracy: 0.1357 - val_loss: 2.0918 - val_accuracy: 0.1233
# Epoch 30/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0808 - accuracy: 0.1176 - val_loss: 2.0920 - val_accuracy: 0.1233
# Epoch 31/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0883 - accuracy: 0.1086 - val_loss: 2.0914 - val_accuracy: 0.1233
# Epoch 32/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0827 - accuracy: 0.1493 - val_loss: 2.0915 - val_accuracy: 0.1233
# Epoch 33/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0989 - accuracy: 0.1222 - val_loss: 2.0920 - val_accuracy: 0.1233
# Epoch 34/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0919 - accuracy: 0.1312 - val_loss: 2.0915 - val_accuracy: 0.1233
# Epoch 35/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0893 - accuracy: 0.1357 - val_loss: 2.0921 - val_accuracy: 0.1233
# Epoch 36/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0894 - accuracy: 0.1176 - val_loss: 2.0916 - val_accuracy: 0.1233
# Epoch 37/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0884 - accuracy: 0.1267 - val_loss: 2.0916 - val_accuracy: 0.1233
# Epoch 38/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0797 - accuracy: 0.1357 - val_loss: 2.0922 - val_accuracy: 0.1233
# Epoch 39/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0857 - accuracy: 0.1176 - val_loss: 2.0919 - val_accuracy: 0.1233
# Epoch 40/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0920 - accuracy: 0.1131 - val_loss: 2.0920 - val_accuracy: 0.1233
# Epoch 41/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0840 - accuracy: 0.1267 - val_loss: 2.0907 - val_accuracy: 0.1233
# Epoch 42/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.1047 - accuracy: 0.1222 - val_loss: 2.0920 - val_accuracy: 0.1233
# Epoch 43/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0839 - accuracy: 0.1176 - val_loss: 2.0920 - val_accuracy: 0.1233
# Epoch 44/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0850 - accuracy: 0.1403 - val_loss: 2.0919 - val_accuracy: 0.1233
# Epoch 45/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0891 - accuracy: 0.1267 - val_loss: 2.0917 - val_accuracy: 0.1233
# Epoch 46/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0874 - accuracy: 0.1176 - val_loss: 2.0911 - val_accuracy: 0.1233
# Epoch 47/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0981 - accuracy: 0.1131 - val_loss: 2.0910 - val_accuracy: 0.1233
# Epoch 48/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0850 - accuracy: 0.1222 - val_loss: 2.0912 - val_accuracy: 0.1233
# Epoch 49/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0983 - accuracy: 0.1222 - val_loss: 2.0911 - val_accuracy: 0.1233
# Epoch 50/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0870 - accuracy: 0.1357 - val_loss: 2.0908 - val_accuracy: 0.1233
# Time : 466.9607415770006
# ================================================================================================================
# <ipython-input-5-211290430dbe>:56: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   result= model.evaluate_generator(test_set) #test_loss, test_acc # ★change
# loss: 2
# accuracy: 0.13699

# %%
# avg pooling 넣은 후

train_set, test_set,val_set = augmentation(target_size = 128, batch_size = 64, class_mode="categorical")

input_tensor = tf.keras.layers.Input(shape=(128, 128, 3))

base_model = EfficientNetV2S(weights='imagenet', include_top=False,input_tensor=input_tensor)

def top_layer():
  # Add a GlobalAveragePooling layer
  x = base_model.output
  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(dense_num, activation='relu')(x)   # ★change
  x = layers.Flatten()(x)
  predictions = Dense(class_num, activation='softmax')(x) # ★change


# rmsp = tf.keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.9)
def for_efficientnet_V2_S(base_model = base_model, top_layer = top_layer(), epoch = 50, optimizer =  "RMSprop", class_num = 8, dense_num = 256):
# Out:
# Found 221 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# ================================================================================================================
# Epoch 1/50
# 4/4 [==============================] - 27s 4s/step - loss: 2.1934 - accuracy: 0.1448 - val_loss: 2.0428 - val_accuracy: 0.1781
# Epoch 2/50
# 4/4 [==============================] - 9s 3s/step - loss: 2.0801 - accuracy: 0.1900 - val_loss: 1.9710 - val_accuracy: 0.2740
# Epoch 3/50
# 4/4 [==============================] - 9s 2s/step - loss: 2.0047 - accuracy: 0.2081 - val_loss: 2.0542 - val_accuracy: 0.1644
# Epoch 4/50
# 4/4 [==============================] - 9s 2s/step - loss: 2.0584 - accuracy: 0.1765 - val_loss: 1.9632 - val_accuracy: 0.1781
# Epoch 5/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9836 - accuracy: 0.2262 - val_loss: 1.9771 - val_accuracy: 0.2055
# Epoch 6/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9430 - accuracy: 0.2624 - val_loss: 2.0009 - val_accuracy: 0.1507
# Epoch 7/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.9261 - accuracy: 0.2489 - val_loss: 1.9253 - val_accuracy: 0.2466
# Epoch 8/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9224 - accuracy: 0.2353 - val_loss: 1.9879 - val_accuracy: 0.2192
# Epoch 9/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.9096 - accuracy: 0.2353 - val_loss: 2.0363 - val_accuracy: 0.1644
# Epoch 10/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9017 - accuracy: 0.2760 - val_loss: 1.9670 - val_accuracy: 0.1781
# Epoch 11/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9198 - accuracy: 0.2579 - val_loss: 1.9580 - val_accuracy: 0.2192
# Epoch 12/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9037 - accuracy: 0.2262 - val_loss: 1.9317 - val_accuracy: 0.2192
# Epoch 13/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.9118 - accuracy: 0.2670 - val_loss: 1.9112 - val_accuracy: 0.2603
# Epoch 14/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8976 - accuracy: 0.2715 - val_loss: 1.9345 - val_accuracy: 0.2329
# Epoch 15/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8944 - accuracy: 0.2941 - val_loss: 1.9118 - val_accuracy: 0.2466
# Epoch 16/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9181 - accuracy: 0.2489 - val_loss: 1.9184 - val_accuracy: 0.2192
# Epoch 17/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8955 - accuracy: 0.2489 - val_loss: 1.9102 - val_accuracy: 0.2740
# Epoch 18/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8452 - accuracy: 0.2624 - val_loss: 1.9580 - val_accuracy: 0.2329
# Epoch 19/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8814 - accuracy: 0.2670 - val_loss: 1.8881 - val_accuracy: 0.2877
# Epoch 20/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.9086 - accuracy: 0.2896 - val_loss: 1.9056 - val_accuracy: 0.2329
# Epoch 21/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8522 - accuracy: 0.2986 - val_loss: 2.0372 - val_accuracy: 0.1918
# Epoch 22/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8526 - accuracy: 0.2941 - val_loss: 1.9014 - val_accuracy: 0.2877
# Epoch 23/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8754 - accuracy: 0.2443 - val_loss: 1.9438 - val_accuracy: 0.2192
# Epoch 24/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8075 - accuracy: 0.3258 - val_loss: 1.9869 - val_accuracy: 0.2329
# Epoch 25/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8413 - accuracy: 0.2670 - val_loss: 1.9088 - val_accuracy: 0.2603
# Epoch 26/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8340 - accuracy: 0.3032 - val_loss: 1.8970 - val_accuracy: 0.2740
# Epoch 27/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8512 - accuracy: 0.2805 - val_loss: 1.8747 - val_accuracy: 0.3014
# Epoch 28/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7829 - accuracy: 0.3213 - val_loss: 1.8653 - val_accuracy: 0.2466
# Epoch 29/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8030 - accuracy: 0.3077 - val_loss: 1.8620 - val_accuracy: 0.2877
# Epoch 30/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7887 - accuracy: 0.2896 - val_loss: 1.8754 - val_accuracy: 0.2740
# Epoch 31/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8106 - accuracy: 0.2986 - val_loss: 1.9103 - val_accuracy: 0.2877
# Epoch 32/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7926 - accuracy: 0.3439 - val_loss: 1.8843 - val_accuracy: 0.2877
# Epoch 33/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8000 - accuracy: 0.3167 - val_loss: 1.9824 - val_accuracy: 0.2055
# Epoch 34/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8172 - accuracy: 0.2851 - val_loss: 1.8793 - val_accuracy: 0.2740
# Epoch 35/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7195 - accuracy: 0.3665 - val_loss: 1.9066 - val_accuracy: 0.1781
# Epoch 36/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7836 - accuracy: 0.2715 - val_loss: 1.8799 - val_accuracy: 0.2740
# Epoch 37/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8015 - accuracy: 0.3303 - val_loss: 1.8623 - val_accuracy: 0.3151
# Epoch 38/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.7623 - accuracy: 0.3077 - val_loss: 1.8528 - val_accuracy: 0.3014
# Epoch 39/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.7627 - accuracy: 0.2986 - val_loss: 1.9186 - val_accuracy: 0.2466
# Epoch 40/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7576 - accuracy: 0.3258 - val_loss: 1.8765 - val_accuracy: 0.2466
# Epoch 41/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7058 - accuracy: 0.3620 - val_loss: 1.9135 - val_accuracy: 0.2740
# Epoch 42/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8065 - accuracy: 0.3032 - val_loss: 1.9949 - val_accuracy: 0.2603
# Epoch 43/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7361 - accuracy: 0.3394 - val_loss: 1.8852 - val_accuracy: 0.2603
# Epoch 44/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7245 - accuracy: 0.3529 - val_loss: 1.8296 - val_accuracy: 0.3288
# Epoch 45/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.7543 - accuracy: 0.3122 - val_loss: 1.8420 - val_accuracy: 0.3014
# Epoch 46/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7383 - accuracy: 0.3575 - val_loss: 1.8468 - val_accuracy: 0.3288
# Epoch 47/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7823 - accuracy: 0.3122 - val_loss: 1.8589 - val_accuracy: 0.2877
# Epoch 48/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.7828 - accuracy: 0.2986 - val_loss: 1.8741 - val_accuracy: 0.2329
# Epoch 49/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.6932 - accuracy: 0.4027 - val_loss: 1.9394 - val_accuracy: 0.2192
# Epoch 50/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8324 - accuracy: 0.2624 - val_loss: 1.8688 - val_accuracy: 0.2603
# Time : 474.3061678720005
# ================================================================================================================
# <ipython-input-65-4a0fa1f0f65e>:60: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   result= model.evaluate_generator(test_set) #test_loss, test_acc # ★change
# loss: 2
# accuracy: 0.21918

# %% [markdown]
# ---

# %%
def for_efficientnet_V2_S(base_model = base_model, epoch = 50, optimizer = Adam(lr=0.001), 
                          class_num = 8, dense_num = 256, target_size = 128, batch_size = 32):
  
  train_set, test_set,val_set = augmentation(target_size, batch_size, class_mode="categorical")

  # freezen the layers
  for layer in base_model.layers:
      layer.trainable = False

  x = base_model.output
  x = layers.GlobalAveragePooling2D()(x)
  predictions = Dense(8, activation='softmax')(x)
  
  # compile the model
  model = Model(inputs=base_model.input, outputs=predictions)
  model.compile(
    optimizer = optimizer, # ★change
    loss='categorical_crossentropy',
    metrics=['accuracy']
  )

  # fit the model
  start = perf_counter()
  history = model.fit(train_set, epochs = epoch, validation_data = val_set) # ★change # ★change # ★change
  end = perf_counter()

  # print the learning time
  print(f"Time : {end-start}")

  result_graph(history, model, test_set)

  return history, model, test_set
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
input_tensor = tf.keras.layers.Input(shape=(128, 128, 3))
base_model = EfficientNetV2S(weights='imagenet', include_top=False,input_tensor=input_tensor)

# rmsp = /tf.keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.9)
history, model, test_set = for_efficientnet_V2_S(base_model = base_model, epoch = 50, optimizer = "RMSprop", class_num = 8, dense_num = 256, target_size = 128, batch_size = 32)
# Out:
# Found 221 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# ================================================================================================================
# Epoch 1/50
# 74/74 [==============================] - 26s 185ms/step - loss: 2.1125 - accuracy: 0.1357 - val_loss: 2.0000 - val_accuracy: 0.1918
# Epoch 2/50
# 74/74 [==============================] - 9s 127ms/step - loss: 2.0313 - accuracy: 0.1900 - val_loss: 1.9763 - val_accuracy: 0.2055
# Epoch 3/50
# 74/74 [==============================] - 9s 128ms/step - loss: 2.0064 - accuracy: 0.2036 - val_loss: 1.9814 - val_accuracy: 0.2192
# Epoch 4/50
# 74/74 [==============================] - 10s 128ms/step - loss: 1.9709 - accuracy: 0.2262 - val_loss: 1.9465 - val_accuracy: 0.2740
# Epoch 5/50
# 74/74 [==============================] - 9s 127ms/step - loss: 1.9753 - accuracy: 0.2489 - val_loss: 1.9710 - val_accuracy: 0.2192
# Epoch 6/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.9969 - accuracy: 0.2081 - val_loss: 1.9876 - val_accuracy: 0.3014
# Epoch 7/50
# 74/74 [==============================] - 9s 125ms/step - loss: 1.9564 - accuracy: 0.2217 - val_loss: 1.9588 - val_accuracy: 0.2055
# Epoch 8/50
# 74/74 [==============================] - 10s 127ms/step - loss: 1.9552 - accuracy: 0.2398 - val_loss: 1.9231 - val_accuracy: 0.3151
# Epoch 9/50
# 74/74 [==============================] - 9s 126ms/step - loss: 1.9571 - accuracy: 0.2398 - val_loss: 1.9455 - val_accuracy: 0.2055
# Epoch 10/50
# 74/74 [==============================] - 9s 127ms/step - loss: 1.9425 - accuracy: 0.2715 - val_loss: 1.9326 - val_accuracy: 0.3014
# Epoch 11/50
# 74/74 [==============================] - 9s 127ms/step - loss: 1.9463 - accuracy: 0.2489 - val_loss: 1.9502 - val_accuracy: 0.1918
# Epoch 12/50
# 74/74 [==============================] - 9s 128ms/step - loss: 1.8832 - accuracy: 0.2986 - val_loss: 1.9344 - val_accuracy: 0.2877
# Epoch 13/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.9137 - accuracy: 0.2715 - val_loss: 1.9393 - val_accuracy: 0.2329
# Epoch 14/50
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8700 - accuracy: 0.2805 - val_loss: 1.9078 - val_accuracy: 0.2466
# Epoch 15/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.9123 - accuracy: 0.2805 - val_loss: 1.9272 - val_accuracy: 0.2466
# Epoch 16/50
# 74/74 [==============================] - 9s 128ms/step - loss: 1.8768 - accuracy: 0.2760 - val_loss: 1.9028 - val_accuracy: 0.2603
# Epoch 17/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.8925 - accuracy: 0.2715 - val_loss: 1.8840 - val_accuracy: 0.2877
# Epoch 18/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.8436 - accuracy: 0.3077 - val_loss: 1.8936 - val_accuracy: 0.2603
# Epoch 19/50
# 74/74 [==============================] - 9s 128ms/step - loss: 1.8817 - accuracy: 0.2805 - val_loss: 1.8601 - val_accuracy: 0.2329
# Epoch 20/50
# 74/74 [==============================] - 9s 127ms/step - loss: 1.8051 - accuracy: 0.3167 - val_loss: 1.8860 - val_accuracy: 0.2329
# Epoch 21/50
# 74/74 [==============================] - 9s 129ms/step - loss: 1.8425 - accuracy: 0.2715 - val_loss: 1.8857 - val_accuracy: 0.2466
# Epoch 22/50
# 74/74 [==============================] - 10s 131ms/step - loss: 1.9071 - accuracy: 0.2805 - val_loss: 1.8958 - val_accuracy: 0.2877
# Epoch 23/50
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8193 - accuracy: 0.2760 - val_loss: 1.9044 - val_accuracy: 0.2466
# Epoch 24/50
# 74/74 [==============================] - 9s 128ms/step - loss: 1.7990 - accuracy: 0.3213 - val_loss: 1.8846 - val_accuracy: 0.2466
# Epoch 25/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.8311 - accuracy: 0.2715 - val_loss: 1.8771 - val_accuracy: 0.2192
# Epoch 26/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.8627 - accuracy: 0.2715 - val_loss: 1.9141 - val_accuracy: 0.2329
# Epoch 27/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.8337 - accuracy: 0.2986 - val_loss: 1.8301 - val_accuracy: 0.2877
# Epoch 28/50
# 74/74 [==============================] - 10s 128ms/step - loss: 1.8304 - accuracy: 0.3167 - val_loss: 1.8475 - val_accuracy: 0.3014
# Epoch 29/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.8484 - accuracy: 0.3167 - val_loss: 1.8675 - val_accuracy: 0.2603
# Epoch 30/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.8668 - accuracy: 0.2896 - val_loss: 1.8655 - val_accuracy: 0.2192
# Epoch 31/50
# 74/74 [==============================] - 10s 130ms/step - loss: 1.7994 - accuracy: 0.3258 - val_loss: 1.8822 - val_accuracy: 0.2877
# Epoch 32/50
# 74/74 [==============================] - 10s 131ms/step - loss: 1.7769 - accuracy: 0.3394 - val_loss: 1.8172 - val_accuracy: 0.2466
# Epoch 33/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.8035 - accuracy: 0.2851 - val_loss: 1.8676 - val_accuracy: 0.2740
# Epoch 34/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.7882 - accuracy: 0.3484 - val_loss: 1.8658 - val_accuracy: 0.2603
# Epoch 35/50
# 74/74 [==============================] - 9s 128ms/step - loss: 1.7751 - accuracy: 0.3394 - val_loss: 1.9032 - val_accuracy: 0.2329
# Epoch 36/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.8064 - accuracy: 0.3122 - val_loss: 1.8712 - val_accuracy: 0.2740
# Epoch 37/50
# 74/74 [==============================] - 10s 130ms/step - loss: 1.8277 - accuracy: 0.2986 - val_loss: 1.8558 - val_accuracy: 0.2466
# Epoch 38/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.7090 - accuracy: 0.3032 - val_loss: 1.9168 - val_accuracy: 0.3151
# Epoch 39/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.7805 - accuracy: 0.3348 - val_loss: 1.9184 - val_accuracy: 0.2466
# Epoch 40/50
# 74/74 [==============================] - 10s 130ms/step - loss: 1.7735 - accuracy: 0.2941 - val_loss: 1.9009 - val_accuracy: 0.2603
# Epoch 41/50
# 74/74 [==============================] - 10s 132ms/step - loss: 1.7969 - accuracy: 0.3348 - val_loss: 1.9195 - val_accuracy: 0.2603
# Epoch 42/50
# 74/74 [==============================] - 9s 129ms/step - loss: 1.7099 - accuracy: 0.3529 - val_loss: 1.9402 - val_accuracy: 0.2603
# Epoch 43/50
# 74/74 [==============================] - 10s 129ms/step - loss: 1.7060 - accuracy: 0.3529 - val_loss: 1.8815 - val_accuracy: 0.2603
# Epoch 44/50
# 74/74 [==============================] - 9s 127ms/step - loss: 1.7923 - accuracy: 0.3258 - val_loss: 1.8761 - val_accuracy: 0.2877
# Epoch 45/50
# 74/74 [==============================] - 9s 127ms/step - loss: 1.7460 - accuracy: 0.3122 - val_loss: 1.8350 - val_accuracy: 0.2466
# Epoch 46/50
# 74/74 [==============================] - 9s 127ms/step - loss: 1.7371 - accuracy: 0.3439 - val_loss: 1.9498 - val_accuracy: 0.2329
# Epoch 47/50
# 74/74 [==============================] - 9s 125ms/step - loss: 1.7803 - accuracy: 0.3620 - val_loss: 1.8240 - val_accuracy: 0.2740
# Epoch 48/50
# 74/74 [==============================] - 9s 126ms/step - loss: 1.7313 - accuracy: 0.3439 - val_loss: 1.8548 - val_accuracy: 0.2877
# Epoch 49/50
# 74/74 [==============================] - 9s 127ms/step - loss: 1.7683 - accuracy: 0.3213 - val_loss: 1.8376 - val_accuracy: 0.2740
# Epoch 50/50
# 74/74 [==============================] - 9s 128ms/step - loss: 1.7031 - accuracy: 0.3620 - val_loss: 1.8655 - val_accuracy: 0.2877
# Time : 492.2795975689987
# ================================================================================================================
# <ipython-input-87-1dcd4f05ad10>:56: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   result= model.evaluate_generator(test_set) #test_loss, test_acc # ★change
# loss: 2
# accuracy: 0.19178
# (<keras.callbacks.History at 0x7f3358595700>,
#  <keras.engine.functional.Functional at 0x7f32b4f60670>)

# %% [markdown]
# ---

# %%
def for_efficientnet_V2_S(base_model = base_model, epoch = 50, optimizer = Adam(lr=0.001), class_num = 8 target_size = 128, batch_size = 32):
  
  train_set, test_set,val_set = augmentation(target_size, batch_size, class_mode="categorical")

  # freezen the layers
  for layer in base_model.layers:
      layer.trainable = False

  x = base_model.output
  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(1024, activation='relu')(x)
  x = layers.Dropout(0.5)(x)
  x = layers.Dense(512, activation='relu')(x)
  predictions = Dense(8, activation='softmax')(x)
  
  # compile the model
  model = Model(inputs=base_model.input, outputs=predictions)
  model.compile(
    optimizer = optimizer, # ★change
    loss='categorical_crossentropy',
    metrics=['accuracy']
  )

  # fit the model
  start = perf_counter()
  history = model.fit(train_set, epochs = epoch, validation_data = val_set) # ★change # ★change # ★change
  end = perf_counter()

  # print the learning time
  print(f"Time : {end-start}")

  result_graph(history, model, test_set)

  return history, model, test_set
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
input_tensor = tf.keras.layers.Input(shape=(128, 128, 3))
base_model = EfficientNetV2S(weights='imagenet', include_top=False,input_tensor=input_tensor)

# rmsp = tf.keras.optimizers.RMSprop(lr=0.001)
history, model, test_set = for_efficientnet_V2_S(base_model = base_model, epoch = 50, optimizer = "adam", class_num = 8, target_size = 128, batch_size = 64)
# Out:
# Found 221 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# ================================================================================================================
# Epoch 1/50
# 4/4 [==============================] - 26s 4s/step - loss: 2.1502 - accuracy: 0.1448 - val_loss: 2.0326 - val_accuracy: 0.1644
# Epoch 2/50
# 4/4 [==============================] - 9s 2s/step - loss: 2.0848 - accuracy: 0.1946 - val_loss: 2.0037 - val_accuracy: 0.2466
# Epoch 3/50
# 4/4 [==============================] - 9s 2s/step - loss: 2.0233 - accuracy: 0.1719 - val_loss: 2.0187 - val_accuracy: 0.2055
# Epoch 4/50
# 4/4 [==============================] - 9s 2s/step - loss: 2.0192 - accuracy: 0.2127 - val_loss: 2.0032 - val_accuracy: 0.1918
# Epoch 5/50
# 4/4 [==============================] - 9s 2s/step - loss: 2.0197 - accuracy: 0.1900 - val_loss: 2.0231 - val_accuracy: 0.1507
# Epoch 6/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9840 - accuracy: 0.2353 - val_loss: 1.9927 - val_accuracy: 0.2055
# Epoch 7/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9753 - accuracy: 0.2262 - val_loss: 1.9709 - val_accuracy: 0.2329
# Epoch 8/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9092 - accuracy: 0.2579 - val_loss: 1.9658 - val_accuracy: 0.2329
# Epoch 9/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9301 - accuracy: 0.2851 - val_loss: 1.9631 - val_accuracy: 0.2192
# Epoch 10/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.9605 - accuracy: 0.2353 - val_loss: 1.9593 - val_accuracy: 0.2055
# Epoch 11/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9336 - accuracy: 0.2353 - val_loss: 1.9310 - val_accuracy: 0.3014
# Epoch 12/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8493 - accuracy: 0.2941 - val_loss: 1.9740 - val_accuracy: 0.1918
# Epoch 13/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9419 - accuracy: 0.2353 - val_loss: 1.9294 - val_accuracy: 0.2466
# Epoch 14/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8753 - accuracy: 0.3167 - val_loss: 1.9913 - val_accuracy: 0.1918
# Epoch 15/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8958 - accuracy: 0.2262 - val_loss: 2.0029 - val_accuracy: 0.2603
# Epoch 16/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9324 - accuracy: 0.2715 - val_loss: 1.9351 - val_accuracy: 0.2740
# Epoch 17/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9604 - accuracy: 0.2534 - val_loss: 1.9575 - val_accuracy: 0.2055
# Epoch 18/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8723 - accuracy: 0.2805 - val_loss: 1.9138 - val_accuracy: 0.2466
# Epoch 19/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8417 - accuracy: 0.2760 - val_loss: 1.9099 - val_accuracy: 0.3014
# Epoch 20/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8551 - accuracy: 0.2941 - val_loss: 1.9617 - val_accuracy: 0.2740
# Epoch 21/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8829 - accuracy: 0.2489 - val_loss: 1.9096 - val_accuracy: 0.2055
# Epoch 22/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.9078 - accuracy: 0.2624 - val_loss: 1.9444 - val_accuracy: 0.2603
# Epoch 23/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8431 - accuracy: 0.2624 - val_loss: 1.9333 - val_accuracy: 0.2877
# Epoch 24/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8932 - accuracy: 0.2760 - val_loss: 1.9690 - val_accuracy: 0.2329
# Epoch 25/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8520 - accuracy: 0.3258 - val_loss: 1.9297 - val_accuracy: 0.2466
# Epoch 26/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8185 - accuracy: 0.3213 - val_loss: 1.9003 - val_accuracy: 0.2329
# Epoch 27/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8856 - accuracy: 0.3167 - val_loss: 1.9144 - val_accuracy: 0.2466
# Epoch 28/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8509 - accuracy: 0.3077 - val_loss: 1.9609 - val_accuracy: 0.2466
# Epoch 29/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8661 - accuracy: 0.2715 - val_loss: 1.9121 - val_accuracy: 0.2329
# Epoch 30/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8777 - accuracy: 0.2670 - val_loss: 1.8935 - val_accuracy: 0.1918
# Epoch 31/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7590 - accuracy: 0.3213 - val_loss: 1.8905 - val_accuracy: 0.2055
# Epoch 32/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8938 - accuracy: 0.2489 - val_loss: 1.9383 - val_accuracy: 0.1918
# Epoch 33/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8576 - accuracy: 0.2624 - val_loss: 1.9558 - val_accuracy: 0.1918
# Epoch 34/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8359 - accuracy: 0.2715 - val_loss: 1.9131 - val_accuracy: 0.2466
# Epoch 35/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.7881 - accuracy: 0.3303 - val_loss: 1.9193 - val_accuracy: 0.2192
# Epoch 36/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7588 - accuracy: 0.2986 - val_loss: 1.9524 - val_accuracy: 0.2740
# Epoch 37/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8220 - accuracy: 0.2851 - val_loss: 1.8882 - val_accuracy: 0.2466
# Epoch 38/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8338 - accuracy: 0.2851 - val_loss: 1.8894 - val_accuracy: 0.2329
# Epoch 39/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8157 - accuracy: 0.3032 - val_loss: 1.9059 - val_accuracy: 0.2192
# Epoch 40/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.7580 - accuracy: 0.3439 - val_loss: 1.9163 - val_accuracy: 0.2877
# Epoch 41/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.8354 - accuracy: 0.3484 - val_loss: 1.9055 - val_accuracy: 0.2740
# Epoch 42/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7847 - accuracy: 0.3258 - val_loss: 1.8555 - val_accuracy: 0.3014
# Epoch 43/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8020 - accuracy: 0.3077 - val_loss: 1.9170 - val_accuracy: 0.2740
# Epoch 44/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.8845 - accuracy: 0.2760 - val_loss: 1.9010 - val_accuracy: 0.2603
# Epoch 45/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.7759 - accuracy: 0.3348 - val_loss: 1.8788 - val_accuracy: 0.3151
# Epoch 46/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7556 - accuracy: 0.3439 - val_loss: 1.9117 - val_accuracy: 0.2466
# Epoch 47/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7656 - accuracy: 0.3348 - val_loss: 1.8730 - val_accuracy: 0.3014
# Epoch 48/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7972 - accuracy: 0.2851 - val_loss: 1.8641 - val_accuracy: 0.2877
# Epoch 49/50
# 4/4 [==============================] - 9s 2s/step - loss: 1.7727 - accuracy: 0.3394 - val_loss: 1.8993 - val_accuracy: 0.2740
# Epoch 50/50
# 4/4 [==============================] - 9s 3s/step - loss: 1.6780 - accuracy: 0.3575 - val_loss: 1.9377 - val_accuracy: 0.2329
# Time : 474.7645834999985
# ================================================================================================================
# <ipython-input-87-1dcd4f05ad10>:56: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   result= model.evaluate_generator(test_set) #test_loss, test_acc # ★change
# loss: 2
# accuracy: 0.12329

# %%
def for_efficientnet_V2_S(base_model = base_model, epoch = 50, optimizer = Adam(lr=0.001), class_num = 8, dense_num = 256, target_size = 128, batch_size = 32):
  
  train_set, test_set,val_set = augmentation(target_size, batch_size, class_mode="categorical")

  # freezen the layers
  for layer in base_model.layers:
      layer.trainable = False

  x = base_model.output
  x = layers.GlobalAveragePooling2D()(x)
  predictions = Dense(8, activation='softmax')(x)
  
  # compile the model
  model = Model(inputs=base_model.input, outputs=predictions)
  model.compile(
    optimizer = optimizer, # ★change
    loss='categorical_crossentropy',
    metrics=['accuracy']
  )

  # fit the model
  start = perf_counter()
  history = model.fit(train_set, epochs = epoch, validation_data = val_set) # ★change # ★change # ★change
  end = perf_counter()

  # print the learning time
  print(f"Time : {end-start}")

  result_graph(history, model, test_set)

  return history, model, test_set
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
input_tensor = tf.keras.layers.Input(shape=(224, 224, 3))
base_model = EfficientNetV2S(weights='imagenet', include_top=False,input_tensor=input_tensor)

# rmsp = tf.keras.optimizers.RMSprop(lr=0.001)
history, model, test_set = for_efficientnet_V2_S(base_model = base_model, epoch = 50, optimizer = "RMSprop", class_num = 8, target_size = 224, batch_size = 32)
# Out:
# Found 221 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# ================================================================================================================
# Epoch 1/50
# 7/7 [==============================] - 27s 2s/step - loss: 2.0766 - accuracy: 0.1674 - val_loss: 2.0497 - val_accuracy: 0.2192
# Epoch 2/50
# 7/7 [==============================] - 10s 2s/step - loss: 2.0411 - accuracy: 0.1719 - val_loss: 2.0353 - val_accuracy: 0.2055
# Epoch 3/50
# 7/7 [==============================] - 11s 2s/step - loss: 2.0352 - accuracy: 0.1946 - val_loss: 2.0307 - val_accuracy: 0.1781
# Epoch 4/50
# 7/7 [==============================] - 11s 2s/step - loss: 2.0227 - accuracy: 0.2217 - val_loss: 2.0292 - val_accuracy: 0.2192
# Epoch 5/50
# 7/7 [==============================] - 10s 2s/step - loss: 2.0007 - accuracy: 0.2353 - val_loss: 2.0252 - val_accuracy: 0.2192
# Epoch 6/50
# 7/7 [==============================] - 10s 1s/step - loss: 2.0064 - accuracy: 0.2036 - val_loss: 2.0226 - val_accuracy: 0.2466
# Epoch 7/50
# 7/7 [==============================] - 10s 1s/step - loss: 1.9861 - accuracy: 0.2353 - val_loss: 2.0138 - val_accuracy: 0.2466
# Epoch 8/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9869 - accuracy: 0.2489 - val_loss: 2.0104 - val_accuracy: 0.2466
# Epoch 9/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9695 - accuracy: 0.2579 - val_loss: 2.0089 - val_accuracy: 0.2603
# Epoch 10/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9818 - accuracy: 0.2217 - val_loss: 2.0008 - val_accuracy: 0.2466
# Epoch 11/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9831 - accuracy: 0.2081 - val_loss: 1.9951 - val_accuracy: 0.2603
# Epoch 12/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.9400 - accuracy: 0.2941 - val_loss: 1.9911 - val_accuracy: 0.2740
# Epoch 13/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.9544 - accuracy: 0.2489 - val_loss: 1.9922 - val_accuracy: 0.2466
# Epoch 14/50
# 7/7 [==============================] - 10s 1s/step - loss: 1.9708 - accuracy: 0.2489 - val_loss: 1.9908 - val_accuracy: 0.2877
# Epoch 15/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.9174 - accuracy: 0.2896 - val_loss: 1.9888 - val_accuracy: 0.2603
# Epoch 16/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9555 - accuracy: 0.2986 - val_loss: 1.9919 - val_accuracy: 0.2877
# Epoch 17/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.9453 - accuracy: 0.2624 - val_loss: 1.9893 - val_accuracy: 0.2603
# Epoch 18/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9400 - accuracy: 0.2579 - val_loss: 1.9899 - val_accuracy: 0.2740
# Epoch 19/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.9176 - accuracy: 0.2805 - val_loss: 1.9847 - val_accuracy: 0.2603
# Epoch 20/50
# 7/7 [==============================] - 10s 1s/step - loss: 1.9264 - accuracy: 0.2579 - val_loss: 1.9883 - val_accuracy: 0.2466
# Epoch 21/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9231 - accuracy: 0.2670 - val_loss: 1.9892 - val_accuracy: 0.2466
# Epoch 22/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9130 - accuracy: 0.2443 - val_loss: 1.9830 - val_accuracy: 0.2603
# Epoch 23/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9325 - accuracy: 0.3213 - val_loss: 1.9840 - val_accuracy: 0.2329
# Epoch 24/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.9029 - accuracy: 0.3032 - val_loss: 1.9902 - val_accuracy: 0.2466
# Epoch 25/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9186 - accuracy: 0.2805 - val_loss: 1.9826 - val_accuracy: 0.2603
# Epoch 26/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.9138 - accuracy: 0.2534 - val_loss: 1.9776 - val_accuracy: 0.2466
# Epoch 27/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.8719 - accuracy: 0.3077 - val_loss: 1.9852 - val_accuracy: 0.2055
# Epoch 28/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9234 - accuracy: 0.2851 - val_loss: 1.9708 - val_accuracy: 0.2603
# Epoch 29/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9084 - accuracy: 0.2941 - val_loss: 1.9721 - val_accuracy: 0.2466
# Epoch 30/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9087 - accuracy: 0.2715 - val_loss: 1.9797 - val_accuracy: 0.2192
# Epoch 31/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9455 - accuracy: 0.2398 - val_loss: 1.9607 - val_accuracy: 0.2877
# Epoch 32/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.8671 - accuracy: 0.3122 - val_loss: 1.9639 - val_accuracy: 0.2740
# Epoch 33/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.8773 - accuracy: 0.3303 - val_loss: 1.9523 - val_accuracy: 0.2740
# Epoch 34/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.8833 - accuracy: 0.2805 - val_loss: 1.9703 - val_accuracy: 0.2466
# Epoch 35/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.9069 - accuracy: 0.2896 - val_loss: 1.9562 - val_accuracy: 0.2877
# Epoch 36/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.8536 - accuracy: 0.2986 - val_loss: 1.9667 - val_accuracy: 0.2466
# Epoch 37/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.8589 - accuracy: 0.3213 - val_loss: 1.9757 - val_accuracy: 0.2466
# Epoch 38/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.8762 - accuracy: 0.2941 - val_loss: 1.9663 - val_accuracy: 0.2192
# Epoch 39/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.8731 - accuracy: 0.3077 - val_loss: 1.9637 - val_accuracy: 0.2603
# Epoch 40/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.8850 - accuracy: 0.3032 - val_loss: 1.9606 - val_accuracy: 0.2877
# Epoch 41/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.8971 - accuracy: 0.3213 - val_loss: 1.9600 - val_accuracy: 0.2740
# Epoch 42/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.8729 - accuracy: 0.3394 - val_loss: 1.9671 - val_accuracy: 0.2466
# Epoch 43/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.9410 - accuracy: 0.2489 - val_loss: 1.9634 - val_accuracy: 0.2055
# Epoch 44/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.8647 - accuracy: 0.3167 - val_loss: 1.9550 - val_accuracy: 0.2603
# Epoch 45/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.8758 - accuracy: 0.2760 - val_loss: 1.9587 - val_accuracy: 0.2603
# Epoch 46/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.8338 - accuracy: 0.3303 - val_loss: 1.9587 - val_accuracy: 0.2329
# Epoch 47/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.8553 - accuracy: 0.2851 - val_loss: 1.9558 - val_accuracy: 0.2466
# Epoch 48/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.8439 - accuracy: 0.3439 - val_loss: 1.9437 - val_accuracy: 0.2603
# Epoch 49/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.8261 - accuracy: 0.3575 - val_loss: 1.9435 - val_accuracy: 0.2603
# Epoch 50/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.8510 - accuracy: 0.3258 - val_loss: 1.9366 - val_accuracy: 0.2877
# Time : 543.4079778539999
# ================================================================================================================
# <ipython-input-98-bef50f677d59>:56: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   result= model.evaluate_generator(test_set) #test_loss, test_acc # ★change
# loss: 2
# accuracy: 0.23288
