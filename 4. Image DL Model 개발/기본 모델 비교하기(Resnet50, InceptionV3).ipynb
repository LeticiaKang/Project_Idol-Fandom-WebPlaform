# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import tensorflow.keras as k
from tensorflow.keras.preprocessing import image

from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2S
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.applications.resnet50 import ResNet50

from tensorflow.keras.models import Model
import tensorflow.keras.layers as layers
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
import numpy as np

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from time import perf_counter, sleep

# %%
# Data augmentation
def augmentation(target_size, batch_size, class_mode="categorical"):
  # print("start")
  train_datagen = ImageDataGenerator(rescale = 1./255,
                                    shear_range = 0.2,
                                    zoom_range = 0.2,
                                    rotation_range=120, 
                                    horizontal_flip = True)

  test_datagen = ImageDataGenerator(rescale = 1./255)

  # Generate training and test sets
  train_set = train_datagen.flow_from_directory(r'/content/drive/MyDrive/테스트용/train',
                                                  target_size = (target_size,target_size),
                                                  batch_size = batch_size,
                                                  class_mode = 'categorical')

  test_set = test_datagen.flow_from_directory(r'/content/drive/MyDrive/테스트용/test',
                                              target_size = (target_size,target_size),                                              # target_size = (299,299),
                                              batch_size = batch_size,
                                              class_mode = 'categorical')

  val_set = test_datagen.flow_from_directory(r'/content/drive/MyDrive/테스트용/val',
                                              target_size = (target_size,target_size),
                                              batch_size = batch_size,
                                              class_mode = 'categorical')
  # print("end")
  print("================================================================================================================")
  return train_set, test_set,val_set

# %% [markdown]
# def for_resnet_50

# %%
def for_resnet_50(base_model, target_size=224, batch_size=128,
                  epoch = 50, optimizer = Adam(lr=1e-6), class_num = 8, pool_size = (7,7)):
  
  train_set, test_set,val_set = augmentation(target_size, batch_size, class_mode="categorical")

  # freezen the layers
  for layer in base_model.layers:
      layer.trainable = False

  # Add a GlobalAveragePooling layer
  x = base_model.output
  x = layers.AveragePooling2D(pool_size = pool_size)(x)  # ★change
  x = layers.Flatten()(x)
  x = layers.Dropout(0.5)(x)
  # fix a number of classes
  predictions = Dense(class_num, activation='softmax')(x) # ★change

  # compile the model
  model = Model(inputs=base_model.input, outputs=predictions)
  model.compile(
    optimizer = optimizer, # ★change
    loss='categorical_crossentropy',
    metrics=['accuracy']
  )

  # fit the model
  start = perf_counter()
  history = model.fit(train_set, epochs = epoch, validation_data = val_set) # ★change # ★change # ★change
  end = perf_counter()

  # print the learning time
  print(f"Time : {end-start}")

  result_graph(history, model, test_set)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %% [markdown]
# ## def result_graph(history):

# %%
def result_graph(history, model, test_set):
   # show the graph of train and validation loss/acc 
  import matplotlib.pyplot as plt
  fig, loss = plt.subplots()

  acc = loss.twinx()

  loss.plot(history.history['loss'], 'y', label='train loss')
  loss.plot(history.history['val_loss'], 'r', label='val loss')

  acc.plot(history.history['accuracy'], 'b', label='train acc')
  acc.plot(history.history['val_accuracy'], 'g', label='val acc')

  loss.set_xlabel('epoch')
  loss.set_ylabel('loss')
  acc.set_ylabel('accuray')

  loss.legend(loc='upper left')
  acc.legend(loc='lower left')

  plt.grid()
  plt.show()
  print("================================================================================================================")

  # Evaluate the model on the test set
  result= model.evaluate_generator(test_set) #test_loss, test_acc # ★change
  print('loss:', round(result[0]))
  print('accuracy:', round(result[1], 5))

# %% [markdown]
# ## def Inception_V3

# %%
def for_Inception_V3(base_model, epoch = 50, target_size = 299, batch_size = 16,
                     optimizer ="adma", class_num = 8):
  
  train_set, test_set,val_set = augmentation(target_size, batch_size, class_mode="categorical")

  # freezen the layers
  for layer in base_model.layers:
      layer.trainable = False

  # Add a GlobalAveragePooling layer
  x = base_model.output
  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(1024, activation='relu')(x)
  x = layers.Dropout(0.2)(x)
  predictions = Dense(class_num, activation='softmax')(x) # ★change

  # compile the model
  model = Model(inputs=base_model.input, outputs=predictions)
  model.compile(
    optimizer = optimizer, # ★change
    loss='categorical_crossentropy',
    metrics=['accuracy']
  )

  # fit the model
  start = perf_counter()
  history = model.fit(train_set, epochs = epoch, validation_data = val_set) # ★change # ★change # ★change
  end = perf_counter()

  # print the learning time
  print(f"Time : {end-start}")

  result_graph(history, model, test_set)

  return history, model, test_set

# %% [markdown]
# ## Resnet50

# %%
train_set, test_set,val_set = augmentation(224, 64, class_mode="categorical")

input_tensor = tf.keras.layers.Input(shape=(224, 224, 3))

base_model = ResNet50(weights='imagenet', include_top = False,input_tensor = input_tensor)

history, model, test_set = for_resnet_50(base_model, target_size=224, batch_size=128,
                                            epoch = 30, optimizer = Adam(lr=1e-6), class_num = 8, pool_size = (7,7))
# Out:
# Found 221 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# ================================================================================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Found 221 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# ================================================================================================================
# Epoch 1/30
# 2/2 [==============================] - 23s 12s/step - loss: 2.6736 - accuracy: 0.1403 - val_loss: 2.1814 - val_accuracy: 0.1096
# Epoch 2/30
# 2/2 [==============================] - 16s 9s/step - loss: 2.3623 - accuracy: 0.1357 - val_loss: 2.1012 - val_accuracy: 0.1370
# Epoch 3/30
# 2/2 [==============================] - 16s 8s/step - loss: 2.3584 - accuracy: 0.1448 - val_loss: 2.0995 - val_accuracy: 0.1233
# Epoch 4/30
# 2/2 [==============================] - 17s 11s/step - loss: 2.3473 - accuracy: 0.1222 - val_loss: 2.1176 - val_accuracy: 0.1233
# Epoch 5/30
# 2/2 [==============================] - 17s 11s/step - loss: 2.3540 - accuracy: 0.1312 - val_loss: 2.1229 - val_accuracy: 0.1644
# Epoch 6/30
# 2/2 [==============================] - 16s 9s/step - loss: 2.2983 - accuracy: 0.1222 - val_loss: 2.1185 - val_accuracy: 0.1781
# Epoch 7/30
# 2/2 [==============================] - 16s 8s/step - loss: 2.2572 - accuracy: 0.1584 - val_loss: 2.1047 - val_accuracy: 0.1233
# Epoch 8/30
# 2/2 [==============================] - 16s 10s/step - loss: 2.2447 - accuracy: 0.1403 - val_loss: 2.0877 - val_accuracy: 0.1370
# Epoch 9/30
# 2/2 [==============================] - 16s 8s/step - loss: 2.2920 - accuracy: 0.1629 - val_loss: 2.0750 - val_accuracy: 0.1233
# Epoch 10/30
# 2/2 [==============================] - 16s 8s/step - loss: 2.2910 - accuracy: 0.1312 - val_loss: 2.0677 - val_accuracy: 0.1370
# Epoch 11/30
# 2/2 [==============================] - 17s 11s/step - loss: 2.2235 - accuracy: 0.1041 - val_loss: 2.0664 - val_accuracy: 0.1918
# Epoch 12/30
# 2/2 [==============================] - 16s 11s/step - loss: 2.1814 - accuracy: 0.1493 - val_loss: 2.0679 - val_accuracy: 0.1644
# Epoch 13/30
# 2/2 [==============================] - 16s 9s/step - loss: 2.2532 - accuracy: 0.1086 - val_loss: 2.0679 - val_accuracy: 0.1644
# Epoch 14/30
# 2/2 [==============================] - 17s 11s/step - loss: 2.2973 - accuracy: 0.0995 - val_loss: 2.0650 - val_accuracy: 0.1781
# Epoch 15/30
# 2/2 [==============================] - 17s 11s/step - loss: 2.1674 - accuracy: 0.1584 - val_loss: 2.0605 - val_accuracy: 0.1781
# Epoch 16/30
# 2/2 [==============================] - 17s 11s/step - loss: 2.1465 - accuracy: 0.1448 - val_loss: 2.0567 - val_accuracy: 0.1644
# Epoch 17/30
# 2/2 [==============================] - 17s 11s/step - loss: 2.1871 - accuracy: 0.1403 - val_loss: 2.0545 - val_accuracy: 0.1644
# Epoch 18/30
# 2/2 [==============================] - 16s 8s/step - loss: 2.1483 - accuracy: 0.1267 - val_loss: 2.0532 - val_accuracy: 0.1918
# Epoch 19/30
# 2/2 [==============================] - 16s 8s/step - loss: 2.1271 - accuracy: 0.1222 - val_loss: 2.0519 - val_accuracy: 0.2603
# Epoch 20/30
# 2/2 [==============================] - 16s 8s/step - loss: 2.1389 - accuracy: 0.1765 - val_loss: 2.0510 - val_accuracy: 0.2192
# Epoch 21/30
# 2/2 [==============================] - 16s 8s/step - loss: 2.1860 - accuracy: 0.1312 - val_loss: 2.0492 - val_accuracy: 0.1918
# Epoch 22/30
# 2/2 [==============================] - 16s 11s/step - loss: 2.1472 - accuracy: 0.1312 - val_loss: 2.0492 - val_accuracy: 0.1644
# Epoch 23/30
# 2/2 [==============================] - 16s 11s/step - loss: 2.0904 - accuracy: 0.1674 - val_loss: 2.0495 - val_accuracy: 0.1644
# Epoch 24/30
# 2/2 [==============================] - 16s 11s/step - loss: 2.0910 - accuracy: 0.2036 - val_loss: 2.0477 - val_accuracy: 0.1507
# Epoch 25/30
# 2/2 [==============================] - 16s 8s/step - loss: 2.1239 - accuracy: 0.1493 - val_loss: 2.0454 - val_accuracy: 0.1644
# Epoch 26/30
# 2/2 [==============================] - 16s 8s/step - loss: 2.0576 - accuracy: 0.1855 - val_loss: 2.0440 - val_accuracy: 0.1507
# Epoch 27/30
# 2/2 [==============================] - 16s 8s/step - loss: 2.0994 - accuracy: 0.1222 - val_loss: 2.0421 - val_accuracy: 0.1096
# Epoch 28/30
# 2/2 [==============================] - 16s 8s/step - loss: 2.0713 - accuracy: 0.1538 - val_loss: 2.0400 - val_accuracy: 0.1918
# Epoch 29/30
# 2/2 [==============================] - 16s 11s/step - loss: 2.1179 - accuracy: 0.1357 - val_loss: 2.0382 - val_accuracy: 0.1507
# Epoch 30/30
# 2/2 [==============================] - 16s 8s/step - loss: 2.0903 - accuracy: 0.1810 - val_loss: 2.0378 - val_accuracy: 0.2192
# Time : 503.19550853200053
# ================================================================================================================
# <ipython-input-25-53204e64e21b>:26: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   result= model.evaluate_generator(test_set) #test_loss, test_acc # ★change
# loss: 2
# accuracy: 0.17808
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-26c431b7b701> in <module>
#       5 base_model = ResNet50(weights='imagenet', include_top = False,input_tensor = input_tensor)
#       6
# ----> 7 history, model, test_set = for_resnet_50(base_model, target_size=224, batch_size=128,
#       8                                             epoch = 30, optimizer = Adam(lr=1e-6), class_num = 8, pool_size = (7,7))
#
# TypeError: cannot unpack non-iterable NoneType object

# %% [markdown]
# ## InceptionV3

# %%
# from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications import InceptionV3

# %%
def for_Inception_V3(base_model, epoch = 50, target_size = 299, batch_size = 16,
                     optimizer ="adma", class_num = 8):
  
  train_set, test_set,val_set = augmentation(target_size, batch_size, class_mode="categorical")

  # freezen the layers
  for layer in base_model.layers:
      layer.trainable = False

  # Add a GlobalAveragePooling layer
  x = base_model.output
  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(1024, activation='relu')(x)
  x = layers.Dropout(0.2)(x)
  predictions = Dense(class_num, activation='softmax')(x) # ★change

  # compile the model
  model = Model(inputs=base_model.input, outputs=predictions)
  model.compile(
    optimizer = optimizer, # ★change
    loss='categorical_crossentropy',
    metrics=['accuracy']
  )

  # fit the model
  start = perf_counter()
  history = model.fit(train_set, epochs = epoch, validation_data = val_set) # ★change # ★change # ★change
  end = perf_counter()

  # print the learning time
  print(f"Time : {end-start}")

  result_graph(history, model, test_set)

  return history, model, test_set

# %%
input_tensor = tf.keras.layers.Input(shape=(299, 299, 3))

base_model = InceptionV3(weights='imagenet', include_top=False,input_tensor=input_tensor)

history, model, test_set = for_Inception_V3(base_model ,  epoch = 50, target_size = 299, batch_size = 16,
                                             optimizer = "adam", class_num = 8)         #Adam(lr=0.001)
# Out:
# Found 221 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# ================================================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-b8240f0ab4e8> in <module>
#       3 base_model = InceptionV3(weights='imagenet', include_top=False,input_tensor=input_tensor)
#       4
# ----> 5 history, model, test_set = for_Inception_V3(base_model ,  epoch = 50, target_size = 299, batch_size = 16,
#       6                                              optimizer = "adam", class_num = 8)         #Adam(lr=0.001)
#
# <ipython-input-28-4d0e8b0a27f1> in for_Inception_V3(base_model, epoch, target_size, batch_size, optimizer, class_num)
#      25   # fit the model
#      26   start = perf_counter()
# ---> 27   history = model.fit(train_set, epochs = epoch, validation_data = val_set) # ★change # ★change # ★change
#      28   end = perf_counter()
#      29
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1588         ):
#    1589             # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1590             data_handler = data_adapter.get_data_handler(
#    1591                 x=x,
#    1592                 y=y,
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1577     if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1578         return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1579     return DataHandler(*args, **kwargs)
#    1580
#    1581
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1257
#    1258         adapter_cls = select_data_adapter(x, y)
# -> 1259         self._adapter = adapter_cls(
#    1260             x,
#    1261             y,
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, shuffle, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#    1006         self._keras_sequence = x
#    1007         self._enqueuer = None
# -> 1008         super().__init__(
#    1009             x,
#    1010             shuffle=False,  # Shuffle is handed in the _make_callable override.
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     865         # Since we have to know the dtype of the python generator when we build
#     866         # the dataset, we have to look at a batch to infer the structure.
# --> 867         peek, x = self._peek_and_restore(x)
#     868         peek = self._standardize_batch(peek)
#     869         peek = _process_tensorlike(peek)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/data_adapter.py in _peek_and_restore(x)
#    1018     @staticmethod
#    1019     def _peek_and_restore(x):
# -> 1020         return x[0], x
#    1021
#    1022     def _handle_multiprocessing(
#
# /usr/local/lib/python3.8/dist-packages/keras/preprocessing/image.py in __getitem__(self, idx)
#     114             self.batch_size * idx : self.batch_size * (idx + 1)
#     115         ]
# --> 116         return self._get_batches_of_transformed_samples(index_array)
#     117
#     118     def __len__(self):
#
# /usr/local/lib/python3.8/dist-packages/keras/preprocessing/image.py in _get_batches_of_transformed_samples(self, index_array)
#     382             if self.image_data_generator:
#     383                 params = self.image_data_generator.get_random_transform(x.shape)
# --> 384                 x = self.image_data_generator.apply_transform(x, params)
#     385                 x = self.image_data_generator.standardize(x)
#     386             batch_x[i] = x
#
# /usr/local/lib/python3.8/dist-packages/keras/preprocessing/image.py in apply_transform(self, x, transform_parameters)
#    2009         img_channel_axis = self.channel_axis - 1
#    2010
# -> 2011         x = apply_affine_transform(
#    2012             x,
#    2013             transform_parameters.get("theta", 0),
#
# /usr/local/lib/python3.8/dist-packages/keras/preprocessing/image.py in apply_affine_transform(x, theta, tx, ty, shear, zx, zy, row_axis, col_axis, channel_axis, fill_mode, cval, order)
#    2607         final_offset = transform_matrix[:2, 2]
#    2608
# -> 2609         channel_images = [
#    2610             ndimage.interpolation.affine_transform(
#    2611                 x_channel,
#
# /usr/local/lib/python3.8/dist-packages/keras/preprocessing/image.py in <listcomp>(.0)
#    2608
#    2609         channel_images = [
# -> 2610             ndimage.interpolation.affine_transform(
#    2611                 x_channel,
#    2612                 final_affine_matrix,
#
# /usr/local/lib/python3.8/dist-packages/scipy/ndimage/interpolation.py in affine_transform(input, matrix, offset, output_shape, output, order, mode, cval, prefilter)
#     609                              mode, cval, npad, False)
#     610     else:
# --> 611         _nd_image.geometric_transform(filtered, None, None, matrix, offset,
#     612                                       output, order, mode, cval, npad, None,
#     613                                       None)
#
# KeyboardInterrupt:

# %% [markdown]
# Inception - try2

# %%
def for_Inception_V3(base_model, epoch = 50, target_size = 299, batch_size = 16,
                     optimizer ="adma", class_num = 8):
  
  train_set, test_set,val_set = augmentation(target_size, batch_size, class_mode="categorical")

  # freezen the layers
  for layer in base_model.layers:
      layer.trainable = False

  # Add a GlobalAveragePooling layer
  x = base_model.output
  x = layers.GlobalMaxPooling2D()(x)
  x = layers.Dense(1024, activation='relu')(x)
  x = layers.Dropout(0.2)(x)
  predictions = Dense(class_num, activation='softmax')(x) # ★change

  # compile the model
  model = Model(inputs=base_model.input, outputs=predictions)
  model.compile(
    optimizer = optimizer, # ★change
    loss='categorical_crossentropy',
    metrics=['accuracy']
  )

  # fit the model
  start = perf_counter()
  history = model.fit(train_set, epochs = epoch, validation_data = val_set) # ★change # ★change # ★change
  end = perf_counter()

  # print the learning time
  print(f"Time : {end-start}")

  result_graph(history, model, test_set)

  return history, model, test_set

# %%
input_tensor = tf.keras.layers.Input(shape=(299, 299, 3))

base_model = InceptionV3(weights='imagenet', include_top=False,input_tensor=input_tensor)

history, model, test_set = for_Inception_V3(base_model ,  epoch = 13, target_size = 299, batch_size = 32, optimizer = "adam", class_num = 8)         #Adam(lr=0.001)
# Out:
# Found 221 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# Found 73 images belonging to 8 classes.
# ================================================================================================================
# Epoch 1/13
# 7/7 [==============================] - 24s 3s/step - loss: 27.7263 - accuracy: 0.1041 - val_loss: 17.5289 - val_accuracy: 0.1233
# Epoch 2/13
# 7/7 [==============================] - 17s 2s/step - loss: 12.8398 - accuracy: 0.1674 - val_loss: 7.2835 - val_accuracy: 0.1233
# Epoch 3/13
# 7/7 [==============================] - 17s 2s/step - loss: 6.3482 - accuracy: 0.2353 - val_loss: 2.9041 - val_accuracy: 0.2740
# Epoch 4/13
# 7/7 [==============================] - 17s 2s/step - loss: 3.3080 - accuracy: 0.2670 - val_loss: 1.7838 - val_accuracy: 0.4521
# Epoch 5/13
# 7/7 [==============================] - 17s 2s/step - loss: 2.0667 - accuracy: 0.3620 - val_loss: 1.8139 - val_accuracy: 0.4932
# Epoch 6/13
# 7/7 [==============================] - 17s 2s/step - loss: 1.8999 - accuracy: 0.3575 - val_loss: 1.3136 - val_accuracy: 0.5342
# Epoch 7/13
# 7/7 [==============================] - 17s 2s/step - loss: 1.4291 - accuracy: 0.4887 - val_loss: 1.2778 - val_accuracy: 0.5342
# Epoch 8/13
# 7/7 [==============================] - 16s 2s/step - loss: 1.1737 - accuracy: 0.6109 - val_loss: 1.0989 - val_accuracy: 0.6027
# Epoch 9/13
# 7/7 [==============================] - 17s 2s/step - loss: 1.0628 - accuracy: 0.6018 - val_loss: 1.0180 - val_accuracy: 0.6575
# Epoch 10/13
# 7/7 [==============================] - 16s 2s/step - loss: 1.0125 - accuracy: 0.6380 - val_loss: 0.9348 - val_accuracy: 0.6986
# Epoch 11/13
# 7/7 [==============================] - 17s 2s/step - loss: 0.9703 - accuracy: 0.6471 - val_loss: 1.0262 - val_accuracy: 0.6438
# Epoch 12/13
# 7/7 [==============================] - 17s 2s/step - loss: 0.8943 - accuracy: 0.7240 - val_loss: 0.8751 - val_accuracy: 0.7397
# Epoch 13/13
# 7/7 [==============================] - 17s 2s/step - loss: 0.9363 - accuracy: 0.6335 - val_loss: 1.1468 - val_accuracy: 0.5890
# Time : 225.90972752800008
# ================================================================================================================
# <ipython-input-25-53204e64e21b>:26: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   result= model.evaluate_generator(test_set) #test_loss, test_acc # ★change
# loss: 1
# accuracy: 0.60274
